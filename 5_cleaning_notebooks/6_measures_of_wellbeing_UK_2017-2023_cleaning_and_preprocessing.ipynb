# %%
# Import necessary libraries & modules
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the data
df = pd.read_csv(r'../4_integrated_csv_files/ons_api_data/wellbeing_quarterly.csv')

# %%
# Exploring and Understanding the Data

# Basic info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   v4_2                  1960 non-null   float64
#  1   LCL                   980 non-null    float64
#  2   UCL                   980 non-null    float64
#  3   yyyy-qq               1960 non-null   object
#  4   Time                  1960 non-null   object
#  5   uk-only               1960 non-null   object
#  6   Geography             1960 non-null   object
#  7   measure-of-wellbeing  1960 non-null   object
#  8   MeasureOfWellbeing    1960 non-null   object
#  9   wellbeing-estimate    1960 non-null   object
#  10  Estimate              1960 non-null   object
#  11  seasonal-adjustment   1960 non-null   object
#  12  SeasonalAdjustment    1960 non-null   object
# dtypes: float64(3), object(10)
# memory usage: 199.2+ KB

# %%
# Checking the top rows of the dataframe
df.head()
# Out:
#    v4_2   LCL   UCL  yyyy-qq     Time    uk-only       Geography  \
# 0   7.5   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
# 1  16.3  15.4  17.2  2023-q1  2023 Q1  K02000001  United Kingdom
# 2  54.1  53.0  55.3  2023-q1  2023 Q1  K02000001  United Kingdom
# 3  23.7  22.8  24.7  2023-q1  2023 Q1  K02000001  United Kingdom
# 4  17.3   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
#
#   measure-of-wellbeing MeasureOfWellbeing wellbeing-estimate        Estimate  \
# 0    life-satisfaction  Life satisfaction       average-mean  Average (mean)
# 1    life-satisfaction  Life satisfaction               fair            Fair
# 2    life-satisfaction  Life satisfaction               good            Good
# 3    life-satisfaction  Life satisfaction          very-good       Very good
# 4            happiness          Happiness               fair            Fair
#
#        seasonal-adjustment       SeasonalAdjustment
# 0      seasonal-adjustment      Seasonally adjusted
# 1  non-seasonal-adjustment  Non-seasonally adjusted
# 2  non-seasonal-adjustment  Non-seasonally adjusted
# 3  non-seasonal-adjustment  Non-seasonally adjusted
# 4      seasonal-adjustment      Seasonally adjusted

# %%
# Checking the ending rows of the dataframe
df.tail()
# Out:
#       v4_2   LCL   UCL  yyyy-qq     Time    uk-only       Geography  \
# 1955  49.7   NaN   NaN  2016-q2  2016 Q2  K02000001  United Kingdom
# 1956   4.4   NaN   NaN  2016-q2  2016 Q2  K02000001  United Kingdom
# 1957  40.4  39.7  41.0  2016-q2  2016 Q2  K02000001  United Kingdom
# 1958  34.8  34.2  35.5  2016-q2  2016 Q2  K02000001  United Kingdom
# 1959  49.7  49.0  50.4  2016-q2  2016 Q2  K02000001  United Kingdom
#
#      measure-of-wellbeing MeasureOfWellbeing wellbeing-estimate   Estimate  \
# 1955           worthwhile         Worthwhile               good       Good
# 1956    life-satisfaction  Life satisfaction               poor       Poor
# 1957            happiness          Happiness               good       Good
# 1958            happiness          Happiness          very-good  Very good
# 1959           worthwhile         Worthwhile               good       Good
#
#           seasonal-adjustment       SeasonalAdjustment
# 1955      seasonal-adjustment      Seasonally adjusted
# 1956      seasonal-adjustment      Seasonally adjusted
# 1957  non-seasonal-adjustment  Non-seasonally adjusted
# 1958  non-seasonal-adjustment  Non-seasonally adjusted
# 1959  non-seasonal-adjustment  Non-seasonally adjusted

# %%
# Random Sample of the dataframe
df.sample()
# Out:
#       v4_2   LCL   UCL  yyyy-qq     Time    uk-only       Geography  \
# 1236  17.7  16.9  18.5  2022-q3  2022 Q3  K02000001  United Kingdom
#
#      measure-of-wellbeing MeasureOfWellbeing wellbeing-estimate Estimate  \
# 1236              anxiety            Anxiety               fair     Fair
#
#           seasonal-adjustment       SeasonalAdjustment
# 1236  non-seasonal-adjustment  Non-seasonally adjusted

# %%
# Checking the shape of the dataframe
print(df.shape)
# Out:
# (1960, 13)

# %%
# Summary statistics of numerical columns
df.describe()
# Out:
#               v4_2         LCL         UCL
# count  1960.000000  980.000000  980.000000
# mean     21.289235   20.791531   21.790204
# std      15.098194   14.886273   15.328285
# min       2.800000    2.800000    2.800000
# 25%       7.700000    7.600000    7.700000
# 50%      17.100000   16.500000   17.650000
# 75%      32.900000   32.200000   33.625000
# max      55.600000   54.500000   56.700000

# %%
# Check for missing values
df.isnull().sum()
# Out:
# v4_2                      0
# LCL                     980
# UCL                     980
# yyyy-qq                   0
# Time                      0
# uk-only                   0
# Geography                 0
# measure-of-wellbeing      0
# MeasureOfWellbeing        0
# wellbeing-estimate        0
# Estimate                  0
# seasonal-adjustment       0
# SeasonalAdjustment        0
# dtype: int64

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Remove duplicate columns: 'measure-of-wellbeing', 'wellbeing-estimate', 'seasonal-adjustment'
df = df.drop(['measure-of-wellbeing', 'wellbeing-estimate', 'seasonal-adjustment'], axis=1)

# %%
df.head()
# Out:
#    v4_2   LCL   UCL  yyyy-qq     Time    uk-only       Geography  \
# 0   7.5   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
# 1  16.3  15.4  17.2  2023-q1  2023 Q1  K02000001  United Kingdom
# 2  54.1  53.0  55.3  2023-q1  2023 Q1  K02000001  United Kingdom
# 3  23.7  22.8  24.7  2023-q1  2023 Q1  K02000001  United Kingdom
# 4  17.3   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
#
#   MeasureOfWellbeing        Estimate       SeasonalAdjustment
# 0  Life satisfaction  Average (mean)      Seasonally adjusted
# 1  Life satisfaction            Fair  Non-seasonally adjusted
# 2  Life satisfaction            Good  Non-seasonally adjusted
# 3  Life satisfaction       Very good  Non-seasonally adjusted
# 4          Happiness            Fair      Seasonally adjusted

# %%
# Split the 'Year' column into 'Year' and 'Quarter'
df[['Year', 'Quarter']] = df['Time'].str.split(' ', expand=True)
print(df)
# Out:
#       v4_2   LCL   UCL  yyyy-qq     Time    uk-only       Geography  \
# 0      7.5   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
# 1     16.3  15.4  17.2  2023-q1  2023 Q1  K02000001  United Kingdom
# 2     54.1  53.0  55.3  2023-q1  2023 Q1  K02000001  United Kingdom
# 3     23.7  22.8  24.7  2023-q1  2023 Q1  K02000001  United Kingdom
# 4     17.3   NaN   NaN  2023-q1  2023 Q1  K02000001  United Kingdom
# ...    ...   ...   ...      ...      ...        ...             ...
# 1955  49.7   NaN   NaN  2016-q2  2016 Q2  K02000001  United Kingdom
# 1956   4.4   NaN   NaN  2016-q2  2016 Q2  K02000001  United Kingdom
# 1957  40.4  39.7  41.0  2016-q2  2016 Q2  K02000001  United Kingdom
# 1958  34.8  34.2  35.5  2016-q2  2016 Q2  K02000001  United Kingdom
# 1959  49.7  49.0  50.4  2016-q2  2016 Q2  K02000001  United Kingdom
#
#      MeasureOfWellbeing        Estimate       SeasonalAdjustment  Year Quarter
# 0     Life satisfaction  Average (mean)      Seasonally adjusted  2023      Q1
# 1     Life satisfaction            Fair  Non-seasonally adjusted  2023      Q1
# 2     Life satisfaction            Good  Non-seasonally adjusted  2023      Q1
# 3     Life satisfaction       Very good  Non-seasonally adjusted  2023      Q1
# 4             Happiness            Fair      Seasonally adjusted  2023      Q1
# ...                 ...             ...                      ...   ...     ...
# 1955         Worthwhile            Good      Seasonally adjusted  2016      Q2
# 1956  Life satisfaction            Poor      Seasonally adjusted  2016      Q2
# 1957          Happiness            Good  Non-seasonally adjusted  2016      Q2
# 1958          Happiness       Very good  Non-seasonally adjusted  2016      Q2
# 1959         Worthwhile            Good  Non-seasonally adjusted  2016      Q2
#
# [1960 rows x 12 columns]

# %%
# Remove additional 'yyyy-qq' column as we have the 'Time' column as well as the 'Year' and 'Quarter
df = df.drop('yyyy-qq', axis=1)

# %%
# Rename columns for clarity and standardisation:
df = df.rename({
    'uk-only': 'UK_Only',
    'MeasureOfWellbeing': 'Measure_Of_Wellbeing',
    'SeasonalAdjustment': 'Seasonal_Adjustment'
    }, axis='columns')

# %%
df.head()
# Out:
#    v4_2   LCL   UCL     Time    UK_Only       Geography Measure_Of_Wellbeing  \
# 0   7.5   NaN   NaN  2023 Q1  K02000001  United Kingdom    Life satisfaction
# 1  16.3  15.4  17.2  2023 Q1  K02000001  United Kingdom    Life satisfaction
# 2  54.1  53.0  55.3  2023 Q1  K02000001  United Kingdom    Life satisfaction
# 3  23.7  22.8  24.7  2023 Q1  K02000001  United Kingdom    Life satisfaction
# 4  17.3   NaN   NaN  2023 Q1  K02000001  United Kingdom            Happiness
#
#          Estimate      Seasonal_Adjustment  Year Quarter
# 0  Average (mean)      Seasonally adjusted  2023      Q1
# 1            Fair  Non-seasonally adjusted  2023      Q1
# 2            Good  Non-seasonally adjusted  2023      Q1
# 3       Very good  Non-seasonally adjusted  2023      Q1
# 4            Fair      Seasonally adjusted  2023      Q1

# %%
# As we are investigating data slightly before and after the peak of Covid-19, we are
# only interested in results from 2017-2023. We can remove any data relating to years 
# prior to 2017.

years_of_interest = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']

# Filter to keep the rows where the specified areas are in our 'Geography' column 
df_filtered = df[df['Year'].isin(years_of_interest)]

# Display the filtered DataFrame
print(df_filtered)
# Out:
#       v4_2   LCL   UCL     Time    UK_Only       Geography  \
# 0      7.5   NaN   NaN  2023 Q1  K02000001  United Kingdom
# 1     16.3  15.4  17.2  2023 Q1  K02000001  United Kingdom
# 2     54.1  53.0  55.3  2023 Q1  K02000001  United Kingdom
# 3     23.7  22.8  24.7  2023 Q1  K02000001  United Kingdom
# 4     17.3   NaN   NaN  2023 Q1  K02000001  United Kingdom
# ...    ...   ...   ...      ...        ...             ...
# 1875  12.0   NaN   NaN  2017 Q4  K02000001  United Kingdom
# 1876   4.4   NaN   NaN  2017 Q4  K02000001  United Kingdom
# 1877   3.7   NaN   NaN  2017 Q4  K02000001  United Kingdom
# 1878  52.5  51.8  53.2  2017 Q4  K02000001  United Kingdom
# 1879  48.9   NaN   NaN  2017 Q4  K02000001  United Kingdom
#
#      Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment  Year  \
# 0       Life satisfaction  Average (mean)      Seasonally adjusted  2023
# 1       Life satisfaction            Fair  Non-seasonally adjusted  2023
# 2       Life satisfaction            Good  Non-seasonally adjusted  2023
# 3       Life satisfaction       Very good  Non-seasonally adjusted  2023
# 4               Happiness            Fair      Seasonally adjusted  2023
# ...                   ...             ...                      ...   ...
# 1875           Worthwhile            Fair      Seasonally adjusted  2017
# 1876    Life satisfaction            Poor      Seasonally adjusted  2017
# 1877           Worthwhile            Poor      Seasonally adjusted  2017
# 1878    Life satisfaction            Good  Non-seasonally adjusted  2017
# 1879           Worthwhile            Good      Seasonally adjusted  2017
#
#      Quarter
# 0         Q1
# 1         Q1
# 2         Q1
# 3         Q1
# 4         Q1
# ...      ...
# 1875      Q4
# 1876      Q4
# 1877      Q4
# 1878      Q4
# 1879      Q4
#
# [1040 rows x 11 columns]

# %%
# Reorder columns so 'Year' and 'Quarter' are next to 'Time'
df_filtered=df_filtered[['v4_2', 'LCL', 'UCL', 'Time', 'Year', 'Quarter', 'UK_Only', 'Geography', 'Measure_Of_Wellbeing', 'Estimate', 'Seasonal_Adjustment']]
print(df_filtered)
# Out:
#       v4_2   LCL   UCL     Time  Year Quarter    UK_Only       Geography  \
# 0      7.5   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 1     16.3  15.4  17.2  2023 Q1  2023      Q1  K02000001  United Kingdom
# 2     54.1  53.0  55.3  2023 Q1  2023      Q1  K02000001  United Kingdom
# 3     23.7  22.8  24.7  2023 Q1  2023      Q1  K02000001  United Kingdom
# 4     17.3   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# ...    ...   ...   ...      ...   ...     ...        ...             ...
# 1875  12.0   NaN   NaN  2017 Q4  2017      Q4  K02000001  United Kingdom
# 1876   4.4   NaN   NaN  2017 Q4  2017      Q4  K02000001  United Kingdom
# 1877   3.7   NaN   NaN  2017 Q4  2017      Q4  K02000001  United Kingdom
# 1878  52.5  51.8  53.2  2017 Q4  2017      Q4  K02000001  United Kingdom
# 1879  48.9   NaN   NaN  2017 Q4  2017      Q4  K02000001  United Kingdom
#
#      Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment
# 0       Life satisfaction  Average (mean)      Seasonally adjusted
# 1       Life satisfaction            Fair  Non-seasonally adjusted
# 2       Life satisfaction            Good  Non-seasonally adjusted
# 3       Life satisfaction       Very good  Non-seasonally adjusted
# 4               Happiness            Fair      Seasonally adjusted
# ...                   ...             ...                      ...
# 1875           Worthwhile            Fair      Seasonally adjusted
# 1876    Life satisfaction            Poor      Seasonally adjusted
# 1877           Worthwhile            Poor      Seasonally adjusted
# 1878    Life satisfaction            Good  Non-seasonally adjusted
# 1879           Worthwhile            Good      Seasonally adjusted
#
# [1040 rows x 11 columns]

# %%
df_filtered.head(25)
# Out:
#     v4_2   LCL   UCL     Time  Year Quarter    UK_Only       Geography  \
# 0    7.5   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 1   16.3  15.4  17.2  2023 Q1  2023      Q1  K02000001  United Kingdom
# 2   54.1  53.0  55.3  2023 Q1  2023      Q1  K02000001  United Kingdom
# 3   23.7  22.8  24.7  2023 Q1  2023      Q1  K02000001  United Kingdom
# 4   17.3   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 5   54.2   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 6   13.3   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 7    7.7   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 8   17.8  16.9  18.7  2023 Q1  2023      Q1  K02000001  United Kingdom
# 9   43.0  42.0  44.1  2023 Q1  2023      Q1  K02000001  United Kingdom
# 10  32.5   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 11  18.3   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 12   7.7   7.7   7.8  2023 Q1  2023      Q1  K02000001  United Kingdom
# 13   7.3   7.3   7.4  2023 Q1  2023      Q1  K02000001  United Kingdom
# 14   4.6   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 15  32.1  31.0  33.1  2023 Q1  2023      Q1  K02000001  United Kingdom
# 16  18.3  17.4  19.2  2023 Q1  2023      Q1  K02000001  United Kingdom
# 17  24.6  23.7  25.6  2023 Q1  2023      Q1  K02000001  United Kingdom
# 18  30.0  29.0  31.0  2023 Q1  2023      Q1  K02000001  United Kingdom
# 19   9.2   8.5   9.9  2023 Q1  2023      Q1  K02000001  United Kingdom
# 20   4.6   4.1   5.1  2023 Q1  2023      Q1  K02000001  United Kingdom
# 21  13.3  12.5  14.1  2023 Q1  2023      Q1  K02000001  United Kingdom
# 22  16.1   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
# 23  33.3  32.3  34.3  2023 Q1  2023      Q1  K02000001  United Kingdom
# 24  33.9   NaN   NaN  2023 Q1  2023      Q1  K02000001  United Kingdom
#
#    Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment
# 0     Life satisfaction  Average (mean)      Seasonally adjusted
# 1     Life satisfaction            Fair  Non-seasonally adjusted
# 2     Life satisfaction            Good  Non-seasonally adjusted
# 3     Life satisfaction       Very good  Non-seasonally adjusted
# 4             Happiness            Fair      Seasonally adjusted
# 5     Life satisfaction            Good      Seasonally adjusted
# 6            Worthwhile            Fair      Seasonally adjusted
# 7            Worthwhile  Average (mean)      Seasonally adjusted
# 8             Happiness            Fair  Non-seasonally adjusted
# 9             Happiness            Good  Non-seasonally adjusted
# 10           Worthwhile       Very good      Seasonally adjusted
# 11              Anxiety            Fair      Seasonally adjusted
# 12           Worthwhile  Average (mean)  Non-seasonally adjusted
# 13            Happiness  Average (mean)  Non-seasonally adjusted
# 14           Worthwhile            Poor      Seasonally adjusted
# 15           Worthwhile       Very good  Non-seasonally adjusted
# 16              Anxiety            Fair  Non-seasonally adjusted
# 17              Anxiety            Good  Non-seasonally adjusted
# 18            Happiness       Very good  Non-seasonally adjusted
# 19            Happiness            Poor  Non-seasonally adjusted
# 20           Worthwhile            Poor  Non-seasonally adjusted
# 21           Worthwhile            Fair  Non-seasonally adjusted
# 22    Life satisfaction            Fair      Seasonally adjusted
# 23              Anxiety       Very good  Non-seasonally adjusted
# 24              Anxiety       Very good      Seasonally adjusted

# %%
# Remove NaN and replace with blank spaces
df_filtered = df_filtered.fillna('')

# %%
# Rearrange data in ascending order from earliest (2017, Q1) to latest (2023, Q4)

# Convert 'Year' to integer
df_filtered['Year'] = df_filtered['Year'].astype(int)

# Convert 'Quarter' to a numerical value (eg: 'Q1'=1, 'Q2'=2)
df_filtered['Quarter'] = df_filtered['Quarter'].astype(str)
df_filtered['Quarter'] = df_filtered['Quarter'].str.extract('(\\d+)').astype(int)

# %%
df_sorted = df_filtered.sort_values(by=['Year', 'Quarter'], ascending=[True, True])
df_sorted.head(25)
# Out:
#       v4_2   LCL   UCL     Time  Year  Quarter    UK_Only       Geography  \
# 1520  29.8  29.1  30.4  2017 Q1  2017        1  K02000001  United Kingdom
# 1521  12.2  11.7  12.7  2017 Q1  2017        1  K02000001  United Kingdom
# 1522  34.8  34.1  35.5  2017 Q1  2017        1  K02000001  United Kingdom
# 1523  49.1              2017 Q1  2017        1  K02000001  United Kingdom
# 1524   8.6              2017 Q1  2017        1  K02000001  United Kingdom
# 1525  40.0              2017 Q1  2017        1  K02000001  United Kingdom
# 1526   7.5   7.4   7.5  2017 Q1  2017        1  K02000001  United Kingdom
# 1527  40.4  39.7  41.1  2017 Q1  2017        1  K02000001  United Kingdom
# 1528   7.7   7.6   7.7  2017 Q1  2017        1  K02000001  United Kingdom
# 1529   4.7   4.4   5.0  2017 Q1  2017        1  K02000001  United Kingdom
# 1530   7.9              2017 Q1  2017        1  K02000001  United Kingdom
# 1531  35.2              2017 Q1  2017        1  K02000001  United Kingdom
# 1532  16.9  16.3  17.4  2017 Q1  2017        1  K02000001  United Kingdom
# 1533  17.0  16.5  17.6  2017 Q1  2017        1  K02000001  United Kingdom
# 1534  22.9              2017 Q1  2017        1  K02000001  United Kingdom
# 1535  33.9  33.2  34.6  2017 Q1  2017        1  K02000001  United Kingdom
# 1536  20.2              2017 Q1  2017        1  K02000001  United Kingdom
# 1537   7.9   7.8   7.9  2017 Q1  2017        1  K02000001  United Kingdom
# 1538  49.1  48.4  49.9  2017 Q1  2017        1  K02000001  United Kingdom
# 1539  30.2              2017 Q1  2017        1  K02000001  United Kingdom
# 1540  39.5  38.8  40.2  2017 Q1  2017        1  K02000001  United Kingdom
# 1541  16.4              2017 Q1  2017        1  K02000001  United Kingdom
# 1542   4.7              2017 Q1  2017        1  K02000001  United Kingdom
# 1543   7.7              2017 Q1  2017        1  K02000001  United Kingdom
# 1544   3.0   2.9   3.0  2017 Q1  2017        1  K02000001  United Kingdom
#
#      Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment
# 1520    Life satisfaction       Very good  Non-seasonally adjusted
# 1521           Worthwhile            Fair  Non-seasonally adjusted
# 1522           Worthwhile       Very good  Non-seasonally adjusted
# 1523           Worthwhile            Good      Seasonally adjusted
# 1524            Happiness            Poor      Seasonally adjusted
# 1525            Happiness            Good      Seasonally adjusted
# 1526            Happiness  Average (mean)  Non-seasonally adjusted
# 1527            Happiness            Good  Non-seasonally adjusted
# 1528    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 1529    Life satisfaction            Poor  Non-seasonally adjusted
# 1530           Worthwhile  Average (mean)      Seasonally adjusted
# 1531           Worthwhile       Very good      Seasonally adjusted
# 1532            Happiness            Fair  Non-seasonally adjusted
# 1533              Anxiety            Fair  Non-seasonally adjusted
# 1534              Anxiety            Good      Seasonally adjusted
# 1535            Happiness       Very good  Non-seasonally adjusted
# 1536              Anxiety            Poor      Seasonally adjusted
# 1537           Worthwhile  Average (mean)  Non-seasonally adjusted
# 1538           Worthwhile            Good  Non-seasonally adjusted
# 1539    Life satisfaction       Very good      Seasonally adjusted
# 1540              Anxiety       Very good  Non-seasonally adjusted
# 1541            Happiness            Fair      Seasonally adjusted
# 1542    Life satisfaction            Poor      Seasonally adjusted
# 1543    Life satisfaction  Average (mean)      Seasonally adjusted
# 1544              Anxiety  Average (mean)  Non-seasonally adjusted

# %%
# Reset the index
df_sorted_reset = df_sorted.reset_index(drop=True)

# %%
# Final Review and Summary

# Check for missing values after cleaning
df_sorted_reset.isnull().sum()

# Verify the data types again
df_sorted_reset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1040 entries, 0 to 1039
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   v4_2                  1040 non-null   float64
#  1   LCL                   1040 non-null   object
#  2   UCL                   1040 non-null   object
#  3   Time                  1040 non-null   object
#  4   Year                  1040 non-null   int64
#  5   Quarter               1040 non-null   int64
#  6   UK_Only               1040 non-null   object
#  7   Geography             1040 non-null   object
#  8   Measure_Of_Wellbeing  1040 non-null   object
#  9   Estimate              1040 non-null   object
#  10  Seasonal_Adjustment   1040 non-null   object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 89.5+ KB

# %%
df_sorted_reset.head(30)
# Out:
#     v4_2   LCL   UCL     Time  Year  Quarter    UK_Only       Geography  \
# 0   29.8  29.1  30.4  2017 Q1  2017        1  K02000001  United Kingdom
# 1   12.2  11.7  12.7  2017 Q1  2017        1  K02000001  United Kingdom
# 2   34.8  34.1  35.5  2017 Q1  2017        1  K02000001  United Kingdom
# 3   49.1              2017 Q1  2017        1  K02000001  United Kingdom
# 4    8.6              2017 Q1  2017        1  K02000001  United Kingdom
# 5   40.0              2017 Q1  2017        1  K02000001  United Kingdom
# 6    7.5   7.4   7.5  2017 Q1  2017        1  K02000001  United Kingdom
# 7   40.4  39.7  41.1  2017 Q1  2017        1  K02000001  United Kingdom
# 8    7.7   7.6   7.7  2017 Q1  2017        1  K02000001  United Kingdom
# 9    4.7   4.4   5.0  2017 Q1  2017        1  K02000001  United Kingdom
# 10   7.9              2017 Q1  2017        1  K02000001  United Kingdom
# 11  35.2              2017 Q1  2017        1  K02000001  United Kingdom
# 12  16.9  16.3  17.4  2017 Q1  2017        1  K02000001  United Kingdom
# 13  17.0  16.5  17.6  2017 Q1  2017        1  K02000001  United Kingdom
# 14  22.9              2017 Q1  2017        1  K02000001  United Kingdom
# 15  33.9  33.2  34.6  2017 Q1  2017        1  K02000001  United Kingdom
# 16  20.2              2017 Q1  2017        1  K02000001  United Kingdom
# 17   7.9   7.8   7.9  2017 Q1  2017        1  K02000001  United Kingdom
# 18  49.1  48.4  49.9  2017 Q1  2017        1  K02000001  United Kingdom
# 19  30.2              2017 Q1  2017        1  K02000001  United Kingdom
# 20  39.5  38.8  40.2  2017 Q1  2017        1  K02000001  United Kingdom
# 21  16.4              2017 Q1  2017        1  K02000001  United Kingdom
# 22   4.7              2017 Q1  2017        1  K02000001  United Kingdom
# 23   7.7              2017 Q1  2017        1  K02000001  United Kingdom
# 24   3.0   2.9   3.0  2017 Q1  2017        1  K02000001  United Kingdom
# 25  20.5  19.9  21.1  2017 Q1  2017        1  K02000001  United Kingdom
# 26  39.8              2017 Q1  2017        1  K02000001  United Kingdom
# 27  13.9  13.4  14.4  2017 Q1  2017        1  K02000001  United Kingdom
# 28   3.8              2017 Q1  2017        1  K02000001  United Kingdom
# 29  12.2              2017 Q1  2017        1  K02000001  United Kingdom
#
#    Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment
# 0     Life satisfaction       Very good  Non-seasonally adjusted
# 1            Worthwhile            Fair  Non-seasonally adjusted
# 2            Worthwhile       Very good  Non-seasonally adjusted
# 3            Worthwhile            Good      Seasonally adjusted
# 4             Happiness            Poor      Seasonally adjusted
# 5             Happiness            Good      Seasonally adjusted
# 6             Happiness  Average (mean)  Non-seasonally adjusted
# 7             Happiness            Good  Non-seasonally adjusted
# 8     Life satisfaction  Average (mean)  Non-seasonally adjusted
# 9     Life satisfaction            Poor  Non-seasonally adjusted
# 10           Worthwhile  Average (mean)      Seasonally adjusted
# 11           Worthwhile       Very good      Seasonally adjusted
# 12            Happiness            Fair  Non-seasonally adjusted
# 13              Anxiety            Fair  Non-seasonally adjusted
# 14              Anxiety            Good      Seasonally adjusted
# 15            Happiness       Very good  Non-seasonally adjusted
# 16              Anxiety            Poor      Seasonally adjusted
# 17           Worthwhile  Average (mean)  Non-seasonally adjusted
# 18           Worthwhile            Good  Non-seasonally adjusted
# 19    Life satisfaction       Very good      Seasonally adjusted
# 20              Anxiety       Very good  Non-seasonally adjusted
# 21            Happiness            Fair      Seasonally adjusted
# 22    Life satisfaction            Poor      Seasonally adjusted
# 23    Life satisfaction  Average (mean)      Seasonally adjusted
# 24              Anxiety  Average (mean)  Non-seasonally adjusted
# 25              Anxiety            Poor  Non-seasonally adjusted
# 26              Anxiety       Very good      Seasonally adjusted
# 27    Life satisfaction            Fair  Non-seasonally adjusted
# 28           Worthwhile            Poor      Seasonally adjusted
# 29           Worthwhile            Fair      Seasonally adjusted

# %%
# Filter data for 'Average (mean)' in the 'Estimates' column for overall trends over the years in each category:

# 1. Filter for "Average (mean)" entries in the Estimate column.
df_avg_mean = df_sorted_reset[df_sorted_reset['Estimate'] == 'Average (mean)']

# 2. Filter for each of the four specific measures of wellbeing in the Measure_Of_Wellbeing column.
measures_of_wellbeing = ['Anxiety', 'Life satisfaction', 'Happiness', 'Worthwhile']

# 3. Combine both filters to get a dataset with only the 'Average (mean)' values for each measure of wellbeing in order 
#   to visualise our results.

df_mean = df_avg_mean[df_avg_mean['Measure_Of_Wellbeing'].isin(measures_of_wellbeing)]

# %%
# Display the filtered data
df_mean.head(50)
# Out:
#      v4_2  LCL  UCL     Time  Year  Quarter    UK_Only       Geography  \
# 6     7.5  7.4  7.5  2017 Q1  2017        1  K02000001  United Kingdom
# 8     7.7  7.6  7.7  2017 Q1  2017        1  K02000001  United Kingdom
# 10    7.9            2017 Q1  2017        1  K02000001  United Kingdom
# 17    7.9  7.8  7.9  2017 Q1  2017        1  K02000001  United Kingdom
# 23    7.7            2017 Q1  2017        1  K02000001  United Kingdom
# 24    3.0  2.9  3.0  2017 Q1  2017        1  K02000001  United Kingdom
# 31    2.9            2017 Q1  2017        1  K02000001  United Kingdom
# 33    7.5            2017 Q1  2017        1  K02000001  United Kingdom
# 41    2.9            2017 Q2  2017        2  K02000001  United Kingdom
# 43    7.5            2017 Q2  2017        2  K02000001  United Kingdom
# 45    7.7            2017 Q2  2017        2  K02000001  United Kingdom
# 49    2.9  2.9  2.9  2017 Q2  2017        2  K02000001  United Kingdom
# 52    7.6  7.5  7.6  2017 Q2  2017        2  K02000001  United Kingdom
# 54    7.9            2017 Q2  2017        2  K02000001  United Kingdom
# 58    7.7  7.7  7.7  2017 Q2  2017        2  K02000001  United Kingdom
# 60    7.9  7.9  7.9  2017 Q2  2017        2  K02000001  United Kingdom
# 83    7.5            2017 Q3  2017        3  K02000001  United Kingdom
# 85    7.5  7.5  7.6  2017 Q3  2017        3  K02000001  United Kingdom
# 95    7.9            2017 Q3  2017        3  K02000001  United Kingdom
# 102   7.7            2017 Q3  2017        3  K02000001  United Kingdom
# 104   2.9  2.9  2.9  2017 Q3  2017        3  K02000001  United Kingdom
# 105   2.9            2017 Q3  2017        3  K02000001  United Kingdom
# 107   7.7  7.7  7.7  2017 Q3  2017        3  K02000001  United Kingdom
# 111   7.9  7.9  7.9  2017 Q3  2017        3  K02000001  United Kingdom
# 124   7.5  7.5  7.5  2017 Q4  2017        4  K02000001  United Kingdom
# 129   7.9            2017 Q4  2017        4  K02000001  United Kingdom
# 143   7.7  7.6  7.7  2017 Q4  2017        4  K02000001  United Kingdom
# 144   7.7            2017 Q4  2017        4  K02000001  United Kingdom
# 146   7.9  7.8  7.9  2017 Q4  2017        4  K02000001  United Kingdom
# 148   2.9            2017 Q4  2017        4  K02000001  United Kingdom
# 150   7.5            2017 Q4  2017        4  K02000001  United Kingdom
# 153   2.9  2.9  3.0  2017 Q4  2017        4  K02000001  United Kingdom
# 167   7.9            2018 Q1  2018        1  K02000001  United Kingdom
# 169   2.9            2018 Q1  2018        1  K02000001  United Kingdom
# 172   7.4  7.4  7.5  2018 Q1  2018        1  K02000001  United Kingdom
# 175   7.7  7.6  7.7  2018 Q1  2018        1  K02000001  United Kingdom
# 183   2.9  2.8  2.9  2018 Q1  2018        1  K02000001  United Kingdom
# 186   7.7            2018 Q1  2018        1  K02000001  United Kingdom
# 188   7.5            2018 Q1  2018        1  K02000001  United Kingdom
# 190   7.9  7.8  7.9  2018 Q1  2018        1  K02000001  United Kingdom
# 201   7.6  7.6  7.7  2018 Q2  2018        2  K02000001  United Kingdom
# 209   7.9  7.9  7.9  2018 Q2  2018        2  K02000001  United Kingdom
# 221   7.7            2018 Q2  2018        2  K02000001  United Kingdom
# 224   7.7  7.7  7.7  2018 Q2  2018        2  K02000001  United Kingdom
# 229   2.8            2018 Q2  2018        2  K02000001  United Kingdom
# 230   7.6            2018 Q2  2018        2  K02000001  United Kingdom
# 231   2.8  2.8  2.8  2018 Q2  2018        2  K02000001  United Kingdom
# 237   7.9            2018 Q2  2018        2  K02000001  United Kingdom
# 247   7.7  7.7  7.7  2018 Q3  2018        3  K02000001  United Kingdom
# 249   2.9            2018 Q3  2018        3  K02000001  United Kingdom
#
#     Measure_Of_Wellbeing        Estimate      Seasonal_Adjustment
# 6              Happiness  Average (mean)  Non-seasonally adjusted
# 8      Life satisfaction  Average (mean)  Non-seasonally adjusted
# 10            Worthwhile  Average (mean)      Seasonally adjusted
# 17            Worthwhile  Average (mean)  Non-seasonally adjusted
# 23     Life satisfaction  Average (mean)      Seasonally adjusted
# 24               Anxiety  Average (mean)  Non-seasonally adjusted
# 31               Anxiety  Average (mean)      Seasonally adjusted
# 33             Happiness  Average (mean)      Seasonally adjusted
# 41               Anxiety  Average (mean)      Seasonally adjusted
# 43             Happiness  Average (mean)      Seasonally adjusted
# 45     Life satisfaction  Average (mean)      Seasonally adjusted
# 49               Anxiety  Average (mean)  Non-seasonally adjusted
# 52             Happiness  Average (mean)  Non-seasonally adjusted
# 54            Worthwhile  Average (mean)      Seasonally adjusted
# 58     Life satisfaction  Average (mean)  Non-seasonally adjusted
# 60            Worthwhile  Average (mean)  Non-seasonally adjusted
# 83             Happiness  Average (mean)      Seasonally adjusted
# 85             Happiness  Average (mean)  Non-seasonally adjusted
# 95            Worthwhile  Average (mean)      Seasonally adjusted
# 102    Life satisfaction  Average (mean)      Seasonally adjusted
# 104              Anxiety  Average (mean)  Non-seasonally adjusted
# 105              Anxiety  Average (mean)      Seasonally adjusted
# 107    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 111           Worthwhile  Average (mean)  Non-seasonally adjusted
# 124            Happiness  Average (mean)  Non-seasonally adjusted
# 129           Worthwhile  Average (mean)      Seasonally adjusted
# 143    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 144    Life satisfaction  Average (mean)      Seasonally adjusted
# 146           Worthwhile  Average (mean)  Non-seasonally adjusted
# 148              Anxiety  Average (mean)      Seasonally adjusted
# 150            Happiness  Average (mean)      Seasonally adjusted
# 153              Anxiety  Average (mean)  Non-seasonally adjusted
# 167           Worthwhile  Average (mean)      Seasonally adjusted
# 169              Anxiety  Average (mean)      Seasonally adjusted
# 172            Happiness  Average (mean)  Non-seasonally adjusted
# 175    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 183              Anxiety  Average (mean)  Non-seasonally adjusted
# 186    Life satisfaction  Average (mean)      Seasonally adjusted
# 188            Happiness  Average (mean)      Seasonally adjusted
# 190           Worthwhile  Average (mean)  Non-seasonally adjusted
# 201            Happiness  Average (mean)  Non-seasonally adjusted
# 209           Worthwhile  Average (mean)  Non-seasonally adjusted
# 221    Life satisfaction  Average (mean)      Seasonally adjusted
# 224    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 229              Anxiety  Average (mean)      Seasonally adjusted
# 230            Happiness  Average (mean)      Seasonally adjusted
# 231              Anxiety  Average (mean)  Non-seasonally adjusted
# 237           Worthwhile  Average (mean)      Seasonally adjusted
# 247    Life satisfaction  Average (mean)  Non-seasonally adjusted
# 249              Anxiety  Average (mean)      Seasonally adjusted

# %%
# Filter the Seasonal_Adjustment column to include only 'Non-seasonally adjusted' 
df_mean_nsa = df_mean[df_mean['Seasonal_Adjustment'] == 'Non-seasonally adjusted']

# %%
output_path = r'../6_cleaned_files/ons_api_data/measures_of_wellbeing_uk_2017_2023_cleaned.csv'
df_mean_nsa.to_csv(output_path, index=False)
