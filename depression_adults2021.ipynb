# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.cm as cm

'''
The depression score is derived using the eight-item Patient Health Questionnaire (PHQ-8) screener. 

Scoring the PHQ-8:
The total score is calculated by adding up the scores for each of the 8 questions. 
The maximum possible score is 24 (if someone rates "nearly every day" on all items), and the minimum possible score is 0 
(if someone rates "not at all" on all items).

Here’s how the score is typically interpreted:

0 to 4: Minimal depression
5 to 9: Mild depression
10 to 14: Moderate depression
15 to 19: Moderately severe depression
20 to 24: Severe depression
'''
# Out:
# '\nThe depression score is derived using the eight-item Patient Health Questionnaire (PHQ-8) screener. \n\nScoring the PHQ-8:\nThe total score is calculated by adding up the scores for each of the 8 questions. \nThe maximum possible score is 24 (if someone rates "nearly every day" on all items), and the minimum possible score is 0 \n(if someone rates "not at all" on all items).\n\nHere’s how the score is typically interpreted:\n\n0 to 4: Minimal depression\n5 to 9: Mild depression\n10 to 14: Moderate depression\n15 to 19: Moderately severe depression\n20 to 24: Severe depression\n'

# %%
df = pd.read_excel('/Users/lisafranchetti/Desktop/depression_in_adults2021.xlsx')

# %%
df
# Out:
#      Unnamed: 0  27 to 31 January  3 to 7 February  10 to 14 February  \
# 0           Age               NaN              NaN                NaN
# 1           NaN               NaN              NaN                NaN
# 2      16 to 24              38.0             36.0               38.0
# 3      25 to 34              25.0             28.0               29.0
# 4      35 to 44              25.0             22.0               24.0
# 5      45 to 54              22.0             21.0               15.0
# 6      55 to 64              15.0             15.0               12.0
# 7      65 to 74              11.0             10.0               12.0
# 8   75 and over              12.0              9.0                7.0
# 9           NaN               NaN              NaN                NaN
# 10          Sex               NaN              NaN                NaN
# 11          Men              17.0             17.0               18.0
# 12        Women              26.0             24.0               23.0
#
#     17 to 21 February  24 to 28 February  3 to 7 March  10 to 14 March  \
# 0                 NaN                NaN           NaN             NaN
# 1                 NaN                NaN           NaN             NaN
# 2                40.0               32.0          36.0            30.0
# 3                28.0               23.0          24.0            24.0
# 4                23.0               21.0          20.0            15.0
# 5                21.0               20.0          18.0            19.0
# 6                19.0               17.0          13.0            15.0
# 7                11.0               17.0           8.0            10.0
# 8                 9.0               13.0           8.0            11.0
# 9                 NaN                NaN           NaN             NaN
# 10                NaN                NaN           NaN             NaN
# 11               19.0               15.0          15.0            16.0
# 12               25.0               26.0          21.0            20.0
#
#     17 to 21 March  24 to 28 March  ...  16 to 20 June  23 to 27 June  \
# 0              NaN             NaN  ...            NaN            NaN
# 1              NaN             NaN  ...            NaN            NaN
# 2             33.0            36.0  ...           31.0           21.0
# 3             24.0            25.0  ...           24.0           21.0
# 4             25.0            20.0  ...           17.0           18.0
# 5             16.0            18.0  ...           15.0           19.0
# 6             17.0            22.0  ...           12.0           14.0
# 7             10.0            10.0  ...           10.0            8.0
# 8              8.0             9.0  ...            9.0            9.0
# 9              NaN             NaN  ...            NaN            NaN
# 10             NaN             NaN  ...            NaN            NaN
# 11            17.0            16.0  ...           14.0           15.0
# 12            23.0            25.0  ...           20.0           18.0
#
#     30 June to 4 July  7 to 11 July  14 to 18 July  21 to 25 July  \
# 0                 NaN           NaN            NaN            NaN
# 1                 NaN           NaN            NaN            NaN
# 2                21.0          32.0           28.0           29.0
# 3                20.0          24.0           21.0           21.0
# 4                19.0          15.0           18.0           17.0
# 5                17.0          16.0           19.0           20.0
# 6                14.0          12.0           13.0           16.0
# 7                 7.0          12.0            8.0            8.0
# 8                 8.0           7.0            8.0            9.0
# 9                 NaN           NaN            NaN            NaN
# 10                NaN           NaN            NaN            NaN
# 11               13.0          13.0           15.0           14.0
# 12               18.0          21.0           19.0           20.0
#
#     28 July to 1 August  4 to 8 August  11 to 15 August  18 to 22 August
# 0                   NaN            NaN              NaN              NaN
# 1                   NaN            NaN              NaN              NaN
# 2                  31.0           26.0             25.0             24.0
# 3                  21.0           21.0             23.0             20.0
# 4                  16.0           14.0             14.0             17.0
# 5                  20.0           15.0             13.0             15.0
# 6                  16.0           14.0             19.0             13.0
# 7                   9.0           10.0             10.0             11.0
# 8                   8.0           10.0              7.0              8.0
# 9                   NaN            NaN              NaN              NaN
# 10                  NaN            NaN              NaN              NaN
# 11                 14.0           14.0             14.0             12.0
# 12                 21.0           18.0             19.0             19.0
#
# [13 rows x 31 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0              object
# 27 to 31 January       float64
# 3 to 7 February        float64
# 10 to 14 February      float64
# 17 to 21 February      float64
# 24 to 28 February      float64
# 3 to 7 March           float64
# 10 to 14 March         float64
# 17 to 21 March         float64
# 24 to 28 March         float64
# 31 March to 4 April    float64
# 7 to 11 April          float64
# 14 to 18 April         float64
# 21 to 25 April         float64
# 28 April to 3 May2     float64
# 5 to 9 May             float64
# 12 to 16 May           float64
# 19 to 23 May           float64
# 26 to 31 May2          float64
# 2 to 6 June            float64
# 9 to 13 June           float64
# 16 to 20 June          float64
# 23 to 27 June          float64
# 30 June to 4 July      float64
# 7 to 11 July           float64
# 14 to 18 July          float64
# 21 to 25 July          float64
# 28 July to 1 August    float64
# 4 to 8 August          float64
# 11 to 15 August        float64
# 18 to 22 August        float64
# dtype: object

# %%
df.fillna('')
# Out:
#      Unnamed: 0 27 to 31 January 3 to 7 February 10 to 14 February  \
# 0           Age
# 1
# 2      16 to 24             38.0            36.0              38.0
# 3      25 to 34             25.0            28.0              29.0
# 4      35 to 44             25.0            22.0              24.0
# 5      45 to 54             22.0            21.0              15.0
# 6      55 to 64             15.0            15.0              12.0
# 7      65 to 74             11.0            10.0              12.0
# 8   75 and over             12.0             9.0               7.0
# 9
# 10          Sex
# 11          Men             17.0            17.0              18.0
# 12        Women             26.0            24.0              23.0
#
#    17 to 21 February 24 to 28 February 3 to 7 March 10 to 14 March  \
# 0
# 1
# 2               40.0              32.0         36.0           30.0
# 3               28.0              23.0         24.0           24.0
# 4               23.0              21.0         20.0           15.0
# 5               21.0              20.0         18.0           19.0
# 6               19.0              17.0         13.0           15.0
# 7               11.0              17.0          8.0           10.0
# 8                9.0              13.0          8.0           11.0
# 9
# 10
# 11              19.0              15.0         15.0           16.0
# 12              25.0              26.0         21.0           20.0
#
#    17 to 21 March 24 to 28 March  ... 16 to 20 June 23 to 27 June  \
# 0                                 ...
# 1                                 ...
# 2            33.0           36.0  ...          31.0          21.0
# 3            24.0           25.0  ...          24.0          21.0
# 4            25.0           20.0  ...          17.0          18.0
# 5            16.0           18.0  ...          15.0          19.0
# 6            17.0           22.0  ...          12.0          14.0
# 7            10.0           10.0  ...          10.0           8.0
# 8             8.0            9.0  ...           9.0           9.0
# 9                                 ...
# 10                                ...
# 11           17.0           16.0  ...          14.0          15.0
# 12           23.0           25.0  ...          20.0          18.0
#
#    30 June to 4 July 7 to 11 July 14 to 18 July 21 to 25 July  \
# 0
# 1
# 2               21.0         32.0          28.0          29.0
# 3               20.0         24.0          21.0          21.0
# 4               19.0         15.0          18.0          17.0
# 5               17.0         16.0          19.0          20.0
# 6               14.0         12.0          13.0          16.0
# 7                7.0         12.0           8.0           8.0
# 8                8.0          7.0           8.0           9.0
# 9
# 10
# 11              13.0         13.0          15.0          14.0
# 12              18.0         21.0          19.0          20.0
#
#    28 July to 1 August 4 to 8 August 11 to 15 August 18 to 22 August
# 0
# 1
# 2                 31.0          26.0            25.0            24.0
# 3                 21.0          21.0            23.0            20.0
# 4                 16.0          14.0            14.0            17.0
# 5                 20.0          15.0            13.0            15.0
# 6                 16.0          14.0            19.0            13.0
# 7                  9.0          10.0            10.0            11.0
# 8                  8.0          10.0             7.0             8.0
# 9
# 10
# 11                14.0          14.0            14.0            12.0
# 12                21.0          18.0            19.0            19.0
#
# [13 rows x 31 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', '27 to 31 January', '3 to 7 February',
#        '10 to 14 February', '17 to 21 February', '24 to 28 February',
#        '3 to 7 March', '10 to 14 March', '17 to 21 March', '24 to 28 March',
#        '31 March to 4 April', '7 to 11 April', '14 to 18 April',
#        '21 to 25 April', '28 April to 3 May2', '5 to 9 May', '12 to 16 May',
#        '19 to 23 May', '26 to 31 May2', '2 to 6 June', '9 to 13 June',
#        '16 to 20 June', '23 to 27 June', '30 June to 4 July', '7 to 11 July',
#        '14 to 18 July', '21 to 25 July', '28 July to 1 August',
#        '4 to 8 August', '11 to 15 August', '18 to 22 August'],
#       dtype='object')

# %%
df.set_index('Unnamed: 0', inplace=True)
df
# Out:
#              27 to 31 January  3 to 7 February  10 to 14 February  \
# Unnamed: 0
# Age                       NaN              NaN                NaN
# NaN                       NaN              NaN                NaN
# 16 to 24                 38.0             36.0               38.0
# 25 to 34                 25.0             28.0               29.0
# 35 to 44                 25.0             22.0               24.0
# 45 to 54                 22.0             21.0               15.0
# 55 to 64                 15.0             15.0               12.0
# 65 to 74                 11.0             10.0               12.0
# 75 and over              12.0              9.0                7.0
# NaN                       NaN              NaN                NaN
# Sex                       NaN              NaN                NaN
# Men                      17.0             17.0               18.0
# Women                    26.0             24.0               23.0
#
#              17 to 21 February  24 to 28 February  3 to 7 March  \
# Unnamed: 0
# Age                        NaN                NaN           NaN
# NaN                        NaN                NaN           NaN
# 16 to 24                  40.0               32.0          36.0
# 25 to 34                  28.0               23.0          24.0
# 35 to 44                  23.0               21.0          20.0
# 45 to 54                  21.0               20.0          18.0
# 55 to 64                  19.0               17.0          13.0
# 65 to 74                  11.0               17.0           8.0
# 75 and over                9.0               13.0           8.0
# NaN                        NaN                NaN           NaN
# Sex                        NaN                NaN           NaN
# Men                       19.0               15.0          15.0
# Women                     25.0               26.0          21.0
#
#              10 to 14 March  17 to 21 March  24 to 28 March  \
# Unnamed: 0
# Age                     NaN             NaN             NaN
# NaN                     NaN             NaN             NaN
# 16 to 24               30.0            33.0            36.0
# 25 to 34               24.0            24.0            25.0
# 35 to 44               15.0            25.0            20.0
# 45 to 54               19.0            16.0            18.0
# 55 to 64               15.0            17.0            22.0
# 65 to 74               10.0            10.0            10.0
# 75 and over            11.0             8.0             9.0
# NaN                     NaN             NaN             NaN
# Sex                     NaN             NaN             NaN
# Men                    16.0            17.0            16.0
# Women                  20.0            23.0            25.0
#
#              31 March to 4 April  ...  16 to 20 June  23 to 27 June  \
# Unnamed: 0                        ...
# Age                          NaN  ...            NaN            NaN
# NaN                          NaN  ...            NaN            NaN
# 16 to 24                    32.0  ...           31.0           21.0
# 25 to 34                    19.0  ...           24.0           21.0
# 35 to 44                    19.0  ...           17.0           18.0
# 45 to 54                    16.0  ...           15.0           19.0
# 55 to 64                    12.0  ...           12.0           14.0
# 65 to 74                    10.0  ...           10.0            8.0
# 75 and over                 15.0  ...            9.0            9.0
# NaN                          NaN  ...            NaN            NaN
# Sex                          NaN  ...            NaN            NaN
# Men                         15.0  ...           14.0           15.0
# Women                       19.0  ...           20.0           18.0
#
#              30 June to 4 July  7 to 11 July  14 to 18 July  21 to 25 July  \
# Unnamed: 0
# Age                        NaN           NaN            NaN            NaN
# NaN                        NaN           NaN            NaN            NaN
# 16 to 24                  21.0          32.0           28.0           29.0
# 25 to 34                  20.0          24.0           21.0           21.0
# 35 to 44                  19.0          15.0           18.0           17.0
# 45 to 54                  17.0          16.0           19.0           20.0
# 55 to 64                  14.0          12.0           13.0           16.0
# 65 to 74                   7.0          12.0            8.0            8.0
# 75 and over                8.0           7.0            8.0            9.0
# NaN                        NaN           NaN            NaN            NaN
# Sex                        NaN           NaN            NaN            NaN
# Men                       13.0          13.0           15.0           14.0
# Women                     18.0          21.0           19.0           20.0
#
#              28 July to 1 August  4 to 8 August  11 to 15 August  \
# Unnamed: 0
# Age                          NaN            NaN              NaN
# NaN                          NaN            NaN              NaN
# 16 to 24                    31.0           26.0             25.0
# 25 to 34                    21.0           21.0             23.0
# 35 to 44                    16.0           14.0             14.0
# 45 to 54                    20.0           15.0             13.0
# 55 to 64                    16.0           14.0             19.0
# 65 to 74                     9.0           10.0             10.0
# 75 and over                  8.0           10.0              7.0
# NaN                          NaN            NaN              NaN
# Sex                          NaN            NaN              NaN
# Men                         14.0           14.0             14.0
# Women                       21.0           18.0             19.0
#
#              18 to 22 August
# Unnamed: 0
# Age                      NaN
# NaN                      NaN
# 16 to 24                24.0
# 25 to 34                20.0
# 35 to 44                17.0
# 45 to 54                15.0
# 55 to 64                13.0
# 65 to 74                11.0
# 75 and over              8.0
# NaN                      NaN
# Sex                      NaN
# Men                     12.0
# Women                   19.0
#
# [13 rows x 30 columns]

# %%
data_16_24 = df.iloc[2, 0:31] 
data_25_34 = df.iloc[3, 0:31] 
data_35_44 = df.iloc[4, 0:31] 
data_45_54 = df.iloc[5, 0:31] 
data_55_64 = df.iloc[6, 0:31] 
data_65_74 = df.iloc[7, 0:31] 
data_75_over = df.iloc[8, 0:31]

# %%
data_16_24
# Out:
# 27 to 31 January       38.0
# 3 to 7 February        36.0
# 10 to 14 February      38.0
# 17 to 21 February      40.0
# 24 to 28 February      32.0
# 3 to 7 March           36.0
# 10 to 14 March         30.0
# 17 to 21 March         33.0
# 24 to 28 March         36.0
# 31 March to 4 April    32.0
# 7 to 11 April          26.0
# 14 to 18 April         30.0
# 21 to 25 April         24.0
# 28 April to 3 May2     32.0
# 5 to 9 May             24.0
# 12 to 16 May           30.0
# 19 to 23 May           23.0
# 26 to 31 May2          30.0
# 2 to 6 June            29.0
# 9 to 13 June           29.0
# 16 to 20 June          31.0
# 23 to 27 June          21.0
# 30 June to 4 July      21.0
# 7 to 11 July           32.0
# 14 to 18 July          28.0
# 21 to 25 July          29.0
# 28 July to 1 August    31.0
# 4 to 8 August          26.0
# 11 to 15 August        25.0
# 18 to 22 August        24.0
# Name: 16 to 24, dtype: float64

# %%
# Shorten column renames with only the first date of each range so graph is less messy
new_column_names = {
    '27 to 31 January': '27 January',
    '3 to 7 February': '3 February',
    '10 to 14 February': '10 February',
    '17 to 21 February': '17 February',
    '24 to 28 February': '24 February',
    '3 to 7 March': '3 March',
    '10 to 14 March': '10 March',
    '17 to 21 March': '17 March',
    '24 to 28 March': '24 March',
    '31 March to 4 April': '31 March',
    '7 to 11 April': '7 April',
    '14 to 18 April': '14 April',
    '21 to 25 April': '21 April',
    '28 April to 3 May2': '28 April',
    '5 to 9 May': '5 May',
    '12 to 16 May': '12 May',
    '19 to 23 May': '19 May',
    '26 to 31 May2': '26 May',
    '2 to 6 June': '2 June',
    '9 to 13 June': '9 June',
    '16 to 20 June': '16 June',
    '23 to 27 June': '23 June',
    '30 June to 4 July': '30 June',
    '7 to 11 July': '7 July',
    '14 to 18 July': '14 July',
    '21 to 25 July': '21 July',
    '28 July to 1 August': '28 July',
    '4 to 8 August': '4 August',
    '11 to 15 August': '11 August',
    '18 to 22 August': '18 August'
}

# Renaming the columns
df.rename(columns=new_column_names, inplace=True)

# Check the updated column names
print(df.columns)
# Out:
# Index(['27 January', '3 February', '10 February', '17 February', '24 February',
#        '3 March', '10 March', '17 March', '24 March', '31 March', '7 April',
#        '14 April', '21 April', '28 April', '5 May', '12 May', '19 May',
#        '26 May', '2 June', '9 June', '16 June', '23 June', '30 June', '7 July',
#        '14 July', '21 July', '28 July', '4 August', '11 August', '18 August'],
#       dtype='object')

# %%
data_dict = {
    '16 to 24': data_16_24,
    '25 to 34': data_25_34,
    '35 to 44': data_35_44,
    '45 to 54': data_45_54,
    '55 to 64': data_55_64,
    '65 to 74': data_65_74,
    '75 and over': data_75_over
}

# Set up the plot size
plt.figure(figsize=(12, 6))

# Use the viridian color palette for plotting
viridian_palette = sns.color_palette("viridis", n_colors=len(data_dict))

# Define the date ranges (x-axis labels)
date_ranges = df.columns[0:31]  # Columns 0 to 31 represent the dates

# Loop through each age group and plot the data
for idx, (age_group, data) in enumerate(data_dict.items()):
    plt.plot(date_ranges, data, label=age_group, marker='o', color=viridian_palette[idx])

# Add labels and title
plt.xlabel('Weekly Dates')
plt.ylabel('PHQ-8 Score')
plt.title('Weekly Trends in Estimates of Moderate to Severe \nDepressive Symptoms January - August 2021')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Display the legend with age group names
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns


# Define the date ranges (x-axis labels)
date_ranges = df.columns[0:31] 

# Set up the plot size
plt.figure(figsize=(12, 6))

# colourblind friendly colour palette
viridian_palette = sns.color_palette("viridis", n_colors=len(data_dict))

# Loop through each age group and plot the data as an area plot
for idx, (age_group, data) in enumerate(data_dict.items()):
    plt.fill_between(date_ranges, data, label=age_group, color=viridian_palette[idx], alpha=0.6)

# Add labels and title
plt.xlabel('Weekly Dates')
plt.ylabel('PHQ-8 Score')
plt.title('Weekly Trends in Estimates of Moderate to Severe \nDepressive Symptoms January - August 2021')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha="right")

# Display the legend with age group names
plt.legend(title='Age Group', bbox_to_anchor=(1.05, 1), loc='upper left')

# Adjust layout for better spacing
plt.tight_layout()

# Show the plot
plt.show()
