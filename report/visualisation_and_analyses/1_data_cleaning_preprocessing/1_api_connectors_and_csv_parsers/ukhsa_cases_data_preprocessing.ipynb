# %% [markdown]
# # UKHSA Cases Data (https://ukhsa-dashboard.data.gov.uk/covid-19-archive-data-download)
# ## Data Extraction and Creation of Data Structure for Final Cleaning
# ### Imports

# %%
import pandas as pd
from pathlib import Path
import re
import os
from IPython.display import display, HTML

# %% [markdown]
# ### Function to stratify all available files/metrics
#
# #### From looking at the directory there are 1178 files spanning 3 years!
#
# ##### I need to come up with a way of grouping by the metric and then combining the dataset across the available years so that we can further analyse the data I manually merged all of the data from the zip online (https://ukhsa-dashboard.data.gov.uk/covid-19-archive-data-download) and restructured it for easier sorting/searching/combining

# %%
def split_by_case(word):
    return re.findall(r'[A-Z][a-z]*', word)

# %%
path_for_vaccine_datasets = '1_raw_databases/ukhsa_cases_data'

directory_path = Path(path_for_vaccine_datasets)

if os.path.isdir(directory_path):
        if os.listdir(directory_path):
            file_list = [f.name for f in directory_path.iterdir() if f.is_file()]

            file_paths = [f'{path_for_vaccine_datasets}/{file}' for file in file_list if file[-4:] == '.csv']
            
            available_data = []
            
            for i, file in enumerate(file_list):
                if file[:-9] not in available_data:
                    available_data.append(file[:-9])
            
            metrics = []
            
            for data in available_data:
                if data not in metrics:
                    ending = data.split('_')[1]
                    age = ""
                    data = data[0].upper() + data[1:]
                    words = split_by_case(data)
                    if words[0] == 'Cum':
                        words[0] = 'Cumulative'
                    metric = ' '.join(map(str, words)) + " " + age + ending.capitalize()
                    metric = metric.replace("L F D", "LFD").replace("P C R", "PCR")
                    metrics.append(metric)
            
            metrics_dictionary = dict(zip(metrics, available_data))
            
            metrics_dictionary = dict(sorted(metrics_dictionary.items()))
            
        if not os.listdir(directory_path):
                google_drive_url = 'https://drive.google.com/file/d/15zuegbX43NG22VrHp8Wz6RC0ohlbZJ19/view?usp=sharing'
                display(HTML(f'<a href="{google_drive_url}" target="_blank">Click here to download the data from Google Drive</a>'))
                print("Click the above link to download the data from Google Drive and save in the directory: report/visualisation_and_analyses/1_data_cleaning_preprocessing/1_api_connectors_and_csv_parsers/1_raw_databases/ukhsa_cases_data")

# %% [markdown]
# ### List of all metrics available

# %%
for i, key in enumerate(metrics_dictionary.keys()):
    print(f"{i + 1}: {key}. ")
# Out:
# 1: Change In New Cases By Specimen Date Ltla.
# 2: Change In New Cases By Specimen Date Nation.
# 3: Change In New Cases By Specimen Date Region.
# 4: Change In New Cases By Specimen Date Utla.
# 5: Cumulative Cases By Publish Date Ltla.
# 6: Cumulative Cases By Publish Date Nation.
# 7: Cumulative Cases By Publish Date Overview.
# 8: Cumulative Cases By Publish Date Rate Ltla.
# 9: Cumulative Cases By Publish Date Rate Nation.
# 10: Cumulative Cases By Publish Date Rate Overview.
# 11: Cumulative Cases By Publish Date Rate Region.
# 12: Cumulative Cases By Publish Date Rate Utla.
# 13: Cumulative Cases By Publish Date Region.
# 14: Cumulative Cases By Publish Date Utla.
# 15: Cumulative Cases By Specimen Date Ltla.
# 16: Cumulative Cases By Specimen Date Nation.
# 17: Cumulative Cases By Specimen Date Overview.
# 18: Cumulative Cases By Specimen Date Rate Ltla.
# 19: Cumulative Cases By Specimen Date Rate Nation.
# 20: Cumulative Cases By Specimen Date Rate Overview.
# 21: Cumulative Cases By Specimen Date Rate Region.
# 22: Cumulative Cases By Specimen Date Rate Utla.
# 23: Cumulative Cases By Specimen Date Region.
# 24: Cumulative Cases By Specimen Date Utla.
# 25: Cumulative Cases LFD Confirmed PCR By Specimen Date Ltla.
# 26: Cumulative Cases LFD Confirmed PCR By Specimen Date Nation.
# 27: Cumulative Cases LFD Confirmed PCR By Specimen Date Region.
# 28: Cumulative Cases LFD Confirmed PCR By Specimen Date Utla.
# 29: Cumulative Cases LFD Only By Specimen Date Ltla.
# 30: Cumulative Cases LFD Only By Specimen Date Nation.
# 31: Cumulative Cases LFD Only By Specimen Date Region.
# 32: Cumulative Cases LFD Only By Specimen Date Utla.
# 33: Cumulative Cases PCR Only By Specimen Date Ltla.
# 34: Cumulative Cases PCR Only By Specimen Date Nation.
# 35: Cumulative Cases PCR Only By Specimen Date Region.
# 36: Cumulative Cases PCR Only By Specimen Date Utla.
# 37: Cumulative Cases Pillar One By Specimen Date Ltla.
# 38: Cumulative Cases Pillar One By Specimen Date Nation.
# 39: Cumulative Cases Pillar One By Specimen Date Rate Ltla.
# 40: Cumulative Cases Pillar One By Specimen Date Rate Nation.
# 41: Cumulative Cases Pillar One By Specimen Date Rate Region.
# 42: Cumulative Cases Pillar One By Specimen Date Rate Utla.
# 43: Cumulative Cases Pillar One By Specimen Date Region.
# 44: Cumulative Cases Pillar One By Specimen Date Utla.
# 45: Cumulative Cases Pillar Two By Specimen Date Ltla.
# 46: Cumulative Cases Pillar Two By Specimen Date Nation.
# 47: Cumulative Cases Pillar Two By Specimen Date Rate Ltla.
# 48: Cumulative Cases Pillar Two By Specimen Date Rate Nation.
# 49: Cumulative Cases Pillar Two By Specimen Date Rate Region.
# 50: Cumulative Cases Pillar Two By Specimen Date Rate Utla.
# 51: Cumulative Cases Pillar Two By Specimen Date Region.
# 52: Cumulative Cases Pillar Two By Specimen Date Utla.
# 53: Cumulative First Episodes By Specimen Date Ltla.
# 54: Cumulative First Episodes By Specimen Date Nation.
# 55: Cumulative First Episodes By Specimen Date Overview.
# 56: Cumulative First Episodes By Specimen Date Rate Ltla.
# 57: Cumulative First Episodes By Specimen Date Rate Nation.
# 58: Cumulative First Episodes By Specimen Date Rate Overview.
# 59: Cumulative First Episodes By Specimen Date Rate Region.
# 60: Cumulative First Episodes By Specimen Date Rate Utla.
# 61: Cumulative First Episodes By Specimen Date Region.
# 62: Cumulative First Episodes By Specimen Date Utla.
# 63: Cumulative Reinfections By Specimen Date Ltla.
# 64: Cumulative Reinfections By Specimen Date Nation.
# 65: Cumulative Reinfections By Specimen Date Overview.
# 66: Cumulative Reinfections By Specimen Date Rate Ltla.
# 67: Cumulative Reinfections By Specimen Date Rate Nation.
# 68: Cumulative Reinfections By Specimen Date Rate Overview.
# 69: Cumulative Reinfections By Specimen Date Rate Region.
# 70: Cumulative Reinfections By Specimen Date Rate Utla.
# 71: Cumulative Reinfections By Specimen Date Region.
# 72: Cumulative Reinfections By Specimen Date Utla.
# 73: Female Cases Nation.
# 74: Female Cases Region.
# 75: Male Cases Nation.
# 76: Male Cases Region.
# 77: New Cases By Publish Date Change Ltla.
# 78: New Cases By Publish Date Change Nation.
# 79: New Cases By Publish Date Change Overview.
# 80: New Cases By Publish Date Change Percentage Ltla.
# 81: New Cases By Publish Date Change Percentage Nation.
# 82: New Cases By Publish Date Change Percentage Overview.
# 83: New Cases By Publish Date Change Percentage Region.
# 84: New Cases By Publish Date Change Percentage Utla.
# 85: New Cases By Publish Date Change Region.
# 86: New Cases By Publish Date Change Utla.
# 87: New Cases By Publish Date Direction Ltla.
# 88: New Cases By Publish Date Direction Nation.
# 89: New Cases By Publish Date Direction Overview.
# 90: New Cases By Publish Date Direction Region.
# 91: New Cases By Publish Date Direction Utla.
# 92: New Cases By Publish Date Ltla.
# 93: New Cases By Publish Date Nation.
# 94: New Cases By Publish Date Overview.
# 95: New Cases By Publish Date Region.
# 96: New Cases By Publish Date Rolling Rate Ltla.
# 97: New Cases By Publish Date Rolling Rate Nation.
# 98: New Cases By Publish Date Rolling Rate Overview.
# 99: New Cases By Publish Date Rolling Rate Region.
# 100: New Cases By Publish Date Rolling Rate Utla.
# 101: New Cases By Publish Date Rolling Sum Ltla.
# 102: New Cases By Publish Date Rolling Sum Nation.
# 103: New Cases By Publish Date Rolling Sum Overview.
# 104: New Cases By Publish Date Rolling Sum Region.
# 105: New Cases By Publish Date Rolling Sum Utla.
# 106: New Cases By Publish Date Utla.
# 107: New Cases By Specimen Date Age Demographics Ltla.
# 108: New Cases By Specimen Date Age Demographics Nation.
# 109: New Cases By Specimen Date Age Demographics Region.
# 110: New Cases By Specimen Date Age Demographics Utla.
# 111: New Cases By Specimen Date Change Ltla.
# 112: New Cases By Specimen Date Change Nation.
# 113: New Cases By Specimen Date Change Overview.
# 114: New Cases By Specimen Date Change Percentage Ltla.
# 115: New Cases By Specimen Date Change Percentage Nation.
# 116: New Cases By Specimen Date Change Percentage Overview.
# 117: New Cases By Specimen Date Change Percentage Region.
# 118: New Cases By Specimen Date Change Percentage Utla.
# 119: New Cases By Specimen Date Change Region.
# 120: New Cases By Specimen Date Change Utla.
# 121: New Cases By Specimen Date Direction Ltla.
# 122: New Cases By Specimen Date Direction Nation.
# 123: New Cases By Specimen Date Direction Overview.
# 124: New Cases By Specimen Date Direction Region.
# 125: New Cases By Specimen Date Direction Utla.
# 126: New Cases By Specimen Date Ltla.
# 127: New Cases By Specimen Date Msoa.
# 128: New Cases By Specimen Date Nation.
# 129: New Cases By Specimen Date Overview.
# 130: New Cases By Specimen Date Rate Ltla.
# 131: New Cases By Specimen Date Rate Nation.
# 132: New Cases By Specimen Date Rate Overview.
# 133: New Cases By Specimen Date Rate Region.
# 134: New Cases By Specimen Date Rate Utla.
# 135: New Cases By Specimen Date Region.
# 136: New Cases By Specimen Date Rolling Rate Ltla.
# 137: New Cases By Specimen Date Rolling Rate Nation.
# 138: New Cases By Specimen Date Rolling Rate Overview.
# 139: New Cases By Specimen Date Rolling Rate Region.
# 140: New Cases By Specimen Date Rolling Rate Utla.
# 141: New Cases By Specimen Date Rolling Sum Ltla.
# 142: New Cases By Specimen Date Rolling Sum Nation.
# 143: New Cases By Specimen Date Rolling Sum Overview.
# 144: New Cases By Specimen Date Rolling Sum Region.
# 145: New Cases By Specimen Date Rolling Sum Utla.
# 146: New Cases By Specimen Date Utla.
# 147: New Cases LFD Confirmed PCR By Specimen Date Ltla.
# 148: New Cases LFD Confirmed PCR By Specimen Date Nation.
# 149: New Cases LFD Confirmed PCR By Specimen Date Region.
# 150: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Ltla.
# 151: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Nation.
# 152: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Region.
# 153: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Utla.
# 154: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Ltla.
# 155: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Nation.
# 156: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Region.
# 157: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Utla.
# 158: New Cases LFD Confirmed PCR By Specimen Date Utla.
# 159: New Cases LFD Only By Specimen Date Ltla.
# 160: New Cases LFD Only By Specimen Date Nation.
# 161: New Cases LFD Only By Specimen Date Region.
# 162: New Cases LFD Only By Specimen Date Rolling Rate Ltla.
# 163: New Cases LFD Only By Specimen Date Rolling Rate Nation.
# 164: New Cases LFD Only By Specimen Date Rolling Rate Region.
# 165: New Cases LFD Only By Specimen Date Rolling Rate Utla.
# 166: New Cases LFD Only By Specimen Date Rolling Sum Ltla.
# 167: New Cases LFD Only By Specimen Date Rolling Sum Nation.
# 168: New Cases LFD Only By Specimen Date Rolling Sum Region.
# 169: New Cases LFD Only By Specimen Date Rolling Sum Utla.
# 170: New Cases LFD Only By Specimen Date Utla.
# 171: New Cases PCR Only By Specimen Date Ltla.
# 172: New Cases PCR Only By Specimen Date Nation.
# 173: New Cases PCR Only By Specimen Date Region.
# 174: New Cases PCR Only By Specimen Date Rolling Rate Ltla.
# 175: New Cases PCR Only By Specimen Date Rolling Rate Nation.
# 176: New Cases PCR Only By Specimen Date Rolling Rate Region.
# 177: New Cases PCR Only By Specimen Date Rolling Rate Utla.
# 178: New Cases PCR Only By Specimen Date Rolling Sum Ltla.
# 179: New Cases PCR Only By Specimen Date Rolling Sum Nation.
# 180: New Cases PCR Only By Specimen Date Rolling Sum Region.
# 181: New Cases PCR Only By Specimen Date Rolling Sum Utla.
# 182: New Cases PCR Only By Specimen Date Utla.
# 183: New Cases Pillar One By Specimen Date Change Ltla.
# 184: New Cases Pillar One By Specimen Date Change Nation.
# 185: New Cases Pillar One By Specimen Date Change Percentage Ltla.
# 186: New Cases Pillar One By Specimen Date Change Percentage Nation.
# 187: New Cases Pillar One By Specimen Date Change Percentage Region.
# 188: New Cases Pillar One By Specimen Date Change Percentage Utla.
# 189: New Cases Pillar One By Specimen Date Change Region.
# 190: New Cases Pillar One By Specimen Date Change Utla.
# 191: New Cases Pillar One By Specimen Date Direction Ltla.
# 192: New Cases Pillar One By Specimen Date Direction Nation.
# 193: New Cases Pillar One By Specimen Date Direction Region.
# 194: New Cases Pillar One By Specimen Date Direction Utla.
# 195: New Cases Pillar One By Specimen Date Ltla.
# 196: New Cases Pillar One By Specimen Date Nation.
# 197: New Cases Pillar One By Specimen Date Region.
# 198: New Cases Pillar One By Specimen Date Rolling Rate Ltla.
# 199: New Cases Pillar One By Specimen Date Rolling Rate Nation.
# 200: New Cases Pillar One By Specimen Date Rolling Rate Region.
# 201: New Cases Pillar One By Specimen Date Rolling Rate Utla.
# 202: New Cases Pillar One By Specimen Date Rolling Sum Ltla.
# 203: New Cases Pillar One By Specimen Date Rolling Sum Nation.
# 204: New Cases Pillar One By Specimen Date Rolling Sum Region.
# 205: New Cases Pillar One By Specimen Date Rolling Sum Utla.
# 206: New Cases Pillar One By Specimen Date Utla.
# 207: New Cases Pillar Two By Specimen Date Change Ltla.
# 208: New Cases Pillar Two By Specimen Date Change Nation.
# 209: New Cases Pillar Two By Specimen Date Change Percentage Ltla.
# 210: New Cases Pillar Two By Specimen Date Change Percentage Nation.
# 211: New Cases Pillar Two By Specimen Date Change Percentage Region.
# 212: New Cases Pillar Two By Specimen Date Change Percentage Utla.
# 213: New Cases Pillar Two By Specimen Date Change Region.
# 214: New Cases Pillar Two By Specimen Date Change Utla.
# 215: New Cases Pillar Two By Specimen Date Direction Ltla.
# 216: New Cases Pillar Two By Specimen Date Direction Nation.
# 217: New Cases Pillar Two By Specimen Date Direction Region.
# 218: New Cases Pillar Two By Specimen Date Direction Utla.
# 219: New Cases Pillar Two By Specimen Date Ltla.
# 220: New Cases Pillar Two By Specimen Date Nation.
# 221: New Cases Pillar Two By Specimen Date Region.
# 222: New Cases Pillar Two By Specimen Date Rolling Rate Ltla.
# 223: New Cases Pillar Two By Specimen Date Rolling Rate Nation.
# 224: New Cases Pillar Two By Specimen Date Rolling Rate Region.
# 225: New Cases Pillar Two By Specimen Date Rolling Rate Utla.
# 226: New Cases Pillar Two By Specimen Date Rolling Sum Ltla.
# 227: New Cases Pillar Two By Specimen Date Rolling Sum Nation.
# 228: New Cases Pillar Two By Specimen Date Rolling Sum Region.
# 229: New Cases Pillar Two By Specimen Date Rolling Sum Utla.
# 230: New Cases Pillar Two By Specimen Date Utla.
# 231: New First Episodes By Specimen Date Age Demographics Ltla.
# 232: New First Episodes By Specimen Date Age Demographics Nation.
# 233: New First Episodes By Specimen Date Age Demographics Region.
# 234: New First Episodes By Specimen Date Age Demographics Utla.
# 235: New First Episodes By Specimen Date Change Ltla.
# 236: New First Episodes By Specimen Date Change Nation.
# 237: New First Episodes By Specimen Date Change Overview.
# 238: New First Episodes By Specimen Date Change Percentage Ltla.
# 239: New First Episodes By Specimen Date Change Percentage Nation.
# 240: New First Episodes By Specimen Date Change Percentage Overview.
# 241: New First Episodes By Specimen Date Change Percentage Region.
# 242: New First Episodes By Specimen Date Change Percentage Utla.
# 243: New First Episodes By Specimen Date Change Region.
# 244: New First Episodes By Specimen Date Change Utla.
# 245: New First Episodes By Specimen Date Direction Ltla.
# 246: New First Episodes By Specimen Date Direction Nation.
# 247: New First Episodes By Specimen Date Direction Overview.
# 248: New First Episodes By Specimen Date Direction Region.
# 249: New First Episodes By Specimen Date Direction Utla.
# 250: New First Episodes By Specimen Date Ltla.
# 251: New First Episodes By Specimen Date Nation.
# 252: New First Episodes By Specimen Date Overview.
# 253: New First Episodes By Specimen Date Region.
# 254: New First Episodes By Specimen Date Rolling Rate Ltla.
# 255: New First Episodes By Specimen Date Rolling Rate Nation.
# 256: New First Episodes By Specimen Date Rolling Rate Overview.
# 257: New First Episodes By Specimen Date Rolling Rate Region.
# 258: New First Episodes By Specimen Date Rolling Rate Utla.
# 259: New First Episodes By Specimen Date Rolling Sum Ltla.
# 260: New First Episodes By Specimen Date Rolling Sum Nation.
# 261: New First Episodes By Specimen Date Rolling Sum Overview.
# 262: New First Episodes By Specimen Date Rolling Sum Region.
# 263: New First Episodes By Specimen Date Rolling Sum Utla.
# 264: New First Episodes By Specimen Date Utla.
# 265: New Reinfections By Specimen Date Age Demographics Ltla.
# 266: New Reinfections By Specimen Date Age Demographics Nation.
# 267: New Reinfections By Specimen Date Age Demographics Region.
# 268: New Reinfections By Specimen Date Age Demographics Utla.
# 269: New Reinfections By Specimen Date Change Ltla.
# 270: New Reinfections By Specimen Date Change Nation.
# 271: New Reinfections By Specimen Date Change Overview.
# 272: New Reinfections By Specimen Date Change Percentage Ltla.
# 273: New Reinfections By Specimen Date Change Percentage Nation.
# 274: New Reinfections By Specimen Date Change Percentage Overview.
# 275: New Reinfections By Specimen Date Change Percentage Region.
# 276: New Reinfections By Specimen Date Change Percentage Utla.
# 277: New Reinfections By Specimen Date Change Region.
# 278: New Reinfections By Specimen Date Change Utla.
# 279: New Reinfections By Specimen Date Direction Ltla.
# 280: New Reinfections By Specimen Date Direction Nation.
# 281: New Reinfections By Specimen Date Direction Overview.
# 282: New Reinfections By Specimen Date Direction Region.
# 283: New Reinfections By Specimen Date Direction Utla.
# 284: New Reinfections By Specimen Date Ltla.
# 285: New Reinfections By Specimen Date Nation.
# 286: New Reinfections By Specimen Date Overview.
# 287: New Reinfections By Specimen Date Region.
# 288: New Reinfections By Specimen Date Rolling Rate Ltla.
# 289: New Reinfections By Specimen Date Rolling Rate Nation.
# 290: New Reinfections By Specimen Date Rolling Rate Overview.
# 291: New Reinfections By Specimen Date Rolling Rate Region.
# 292: New Reinfections By Specimen Date Rolling Rate Utla.
# 293: New Reinfections By Specimen Date Rolling Sum Ltla.
# 294: New Reinfections By Specimen Date Rolling Sum Nation.
# 295: New Reinfections By Specimen Date Rolling Sum Overview.
# 296: New Reinfections By Specimen Date Rolling Sum Region.
# 297: New Reinfections By Specimen Date Rolling Sum Utla.
# 298: New Reinfections By Specimen Date Utla.
# 299: Previously Reported New Cases By Specimen Date Ltla.
# 300: Previously Reported New Cases By Specimen Date Nation.
# 301: Previously Reported New Cases By Specimen Date Region.
# 302: Previously Reported New Cases By Specimen Date Utla.
# 303: Variants Nation.
# 304: Variants Region.

# %% [markdown]
# ### List of the regional metrics available

# %%
for i, key in enumerate(metrics_dictionary.keys()):
    if "Region" in key:
        print(f"{i + 1}: {key}. ")
# Out:
# 3: Change In New Cases By Specimen Date Region.
# 11: Cumulative Cases By Publish Date Rate Region.
# 13: Cumulative Cases By Publish Date Region.
# 21: Cumulative Cases By Specimen Date Rate Region.
# 23: Cumulative Cases By Specimen Date Region.
# 27: Cumulative Cases LFD Confirmed PCR By Specimen Date Region.
# 31: Cumulative Cases LFD Only By Specimen Date Region.
# 35: Cumulative Cases PCR Only By Specimen Date Region.
# 41: Cumulative Cases Pillar One By Specimen Date Rate Region.
# 43: Cumulative Cases Pillar One By Specimen Date Region.
# 49: Cumulative Cases Pillar Two By Specimen Date Rate Region.
# 51: Cumulative Cases Pillar Two By Specimen Date Region.
# 59: Cumulative First Episodes By Specimen Date Rate Region.
# 61: Cumulative First Episodes By Specimen Date Region.
# 69: Cumulative Reinfections By Specimen Date Rate Region.
# 71: Cumulative Reinfections By Specimen Date Region.
# 74: Female Cases Region.
# 76: Male Cases Region.
# 83: New Cases By Publish Date Change Percentage Region.
# 85: New Cases By Publish Date Change Region.
# 90: New Cases By Publish Date Direction Region.
# 95: New Cases By Publish Date Region.
# 99: New Cases By Publish Date Rolling Rate Region.
# 104: New Cases By Publish Date Rolling Sum Region.
# 109: New Cases By Specimen Date Age Demographics Region.
# 117: New Cases By Specimen Date Change Percentage Region.
# 119: New Cases By Specimen Date Change Region.
# 124: New Cases By Specimen Date Direction Region.
# 133: New Cases By Specimen Date Rate Region.
# 135: New Cases By Specimen Date Region.
# 139: New Cases By Specimen Date Rolling Rate Region.
# 144: New Cases By Specimen Date Rolling Sum Region.
# 149: New Cases LFD Confirmed PCR By Specimen Date Region.
# 152: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Region.
# 156: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Region.
# 161: New Cases LFD Only By Specimen Date Region.
# 164: New Cases LFD Only By Specimen Date Rolling Rate Region.
# 168: New Cases LFD Only By Specimen Date Rolling Sum Region.
# 173: New Cases PCR Only By Specimen Date Region.
# 176: New Cases PCR Only By Specimen Date Rolling Rate Region.
# 180: New Cases PCR Only By Specimen Date Rolling Sum Region.
# 187: New Cases Pillar One By Specimen Date Change Percentage Region.
# 189: New Cases Pillar One By Specimen Date Change Region.
# 193: New Cases Pillar One By Specimen Date Direction Region.
# 197: New Cases Pillar One By Specimen Date Region.
# 200: New Cases Pillar One By Specimen Date Rolling Rate Region.
# 204: New Cases Pillar One By Specimen Date Rolling Sum Region.
# 211: New Cases Pillar Two By Specimen Date Change Percentage Region.
# 213: New Cases Pillar Two By Specimen Date Change Region.
# 217: New Cases Pillar Two By Specimen Date Direction Region.
# 221: New Cases Pillar Two By Specimen Date Region.
# 224: New Cases Pillar Two By Specimen Date Rolling Rate Region.
# 228: New Cases Pillar Two By Specimen Date Rolling Sum Region.
# 233: New First Episodes By Specimen Date Age Demographics Region.
# 241: New First Episodes By Specimen Date Change Percentage Region.
# 243: New First Episodes By Specimen Date Change Region.
# 248: New First Episodes By Specimen Date Direction Region.
# 253: New First Episodes By Specimen Date Region.
# 257: New First Episodes By Specimen Date Rolling Rate Region.
# 262: New First Episodes By Specimen Date Rolling Sum Region.
# 267: New Reinfections By Specimen Date Age Demographics Region.
# 275: New Reinfections By Specimen Date Change Percentage Region.
# 277: New Reinfections By Specimen Date Change Region.
# 282: New Reinfections By Specimen Date Direction Region.
# 287: New Reinfections By Specimen Date Region.
# 291: New Reinfections By Specimen Date Rolling Rate Region.
# 296: New Reinfections By Specimen Date Rolling Sum Region.
# 301: Previously Reported New Cases By Specimen Date Region.
# 304: Variants Region.

# %% [markdown]
# ### List of the national metrics available

# %%
for i, key in enumerate(metrics_dictionary.keys()):
    if "Nation" in key:
        print(f"{i + 1}: {key}. ")
# Out:
# 2: Change In New Cases By Specimen Date Nation.
# 6: Cumulative Cases By Publish Date Nation.
# 9: Cumulative Cases By Publish Date Rate Nation.
# 16: Cumulative Cases By Specimen Date Nation.
# 19: Cumulative Cases By Specimen Date Rate Nation.
# 26: Cumulative Cases LFD Confirmed PCR By Specimen Date Nation.
# 30: Cumulative Cases LFD Only By Specimen Date Nation.
# 34: Cumulative Cases PCR Only By Specimen Date Nation.
# 38: Cumulative Cases Pillar One By Specimen Date Nation.
# 40: Cumulative Cases Pillar One By Specimen Date Rate Nation.
# 46: Cumulative Cases Pillar Two By Specimen Date Nation.
# 48: Cumulative Cases Pillar Two By Specimen Date Rate Nation.
# 54: Cumulative First Episodes By Specimen Date Nation.
# 57: Cumulative First Episodes By Specimen Date Rate Nation.
# 64: Cumulative Reinfections By Specimen Date Nation.
# 67: Cumulative Reinfections By Specimen Date Rate Nation.
# 73: Female Cases Nation.
# 75: Male Cases Nation.
# 78: New Cases By Publish Date Change Nation.
# 81: New Cases By Publish Date Change Percentage Nation.
# 88: New Cases By Publish Date Direction Nation.
# 93: New Cases By Publish Date Nation.
# 97: New Cases By Publish Date Rolling Rate Nation.
# 102: New Cases By Publish Date Rolling Sum Nation.
# 108: New Cases By Specimen Date Age Demographics Nation.
# 112: New Cases By Specimen Date Change Nation.
# 115: New Cases By Specimen Date Change Percentage Nation.
# 122: New Cases By Specimen Date Direction Nation.
# 128: New Cases By Specimen Date Nation.
# 131: New Cases By Specimen Date Rate Nation.
# 137: New Cases By Specimen Date Rolling Rate Nation.
# 142: New Cases By Specimen Date Rolling Sum Nation.
# 148: New Cases LFD Confirmed PCR By Specimen Date Nation.
# 151: New Cases LFD Confirmed PCR By Specimen Date Rolling Rate Nation.
# 155: New Cases LFD Confirmed PCR By Specimen Date Rolling Sum Nation.
# 160: New Cases LFD Only By Specimen Date Nation.
# 163: New Cases LFD Only By Specimen Date Rolling Rate Nation.
# 167: New Cases LFD Only By Specimen Date Rolling Sum Nation.
# 172: New Cases PCR Only By Specimen Date Nation.
# 175: New Cases PCR Only By Specimen Date Rolling Rate Nation.
# 179: New Cases PCR Only By Specimen Date Rolling Sum Nation.
# 184: New Cases Pillar One By Specimen Date Change Nation.
# 186: New Cases Pillar One By Specimen Date Change Percentage Nation.
# 192: New Cases Pillar One By Specimen Date Direction Nation.
# 196: New Cases Pillar One By Specimen Date Nation.
# 199: New Cases Pillar One By Specimen Date Rolling Rate Nation.
# 203: New Cases Pillar One By Specimen Date Rolling Sum Nation.
# 208: New Cases Pillar Two By Specimen Date Change Nation.
# 210: New Cases Pillar Two By Specimen Date Change Percentage Nation.
# 216: New Cases Pillar Two By Specimen Date Direction Nation.
# 220: New Cases Pillar Two By Specimen Date Nation.
# 223: New Cases Pillar Two By Specimen Date Rolling Rate Nation.
# 227: New Cases Pillar Two By Specimen Date Rolling Sum Nation.
# 232: New First Episodes By Specimen Date Age Demographics Nation.
# 236: New First Episodes By Specimen Date Change Nation.
# 239: New First Episodes By Specimen Date Change Percentage Nation.
# 246: New First Episodes By Specimen Date Direction Nation.
# 251: New First Episodes By Specimen Date Nation.
# 255: New First Episodes By Specimen Date Rolling Rate Nation.
# 260: New First Episodes By Specimen Date Rolling Sum Nation.
# 266: New Reinfections By Specimen Date Age Demographics Nation.
# 270: New Reinfections By Specimen Date Change Nation.
# 273: New Reinfections By Specimen Date Change Percentage Nation.
# 280: New Reinfections By Specimen Date Direction Nation.
# 285: New Reinfections By Specimen Date Nation.
# 289: New Reinfections By Specimen Date Rolling Rate Nation.
# 294: New Reinfections By Specimen Date Rolling Sum Nation.
# 300: Previously Reported New Cases By Specimen Date Nation.
# 303: Variants Nation.

# %% [markdown]
# ### Select a statistic to combine data across years into a dataframe for further analysis/save as csv
#
# #### Change the number below to generate a dataframe of your desired metric which can be saved as a csv

# %%
# Metrics selected for cleaning & processing: 135, 139, 99, 149, 161, 173, 233, 267, 75

# %%
selected_data = 135

# %%
keys = list(metrics_dictionary.keys())

selected_key = keys[selected_data - 1]

selected_metric = metrics_dictionary[selected_key]

# %%
available_files_for_metric = []

for file in file_paths:
    if selected_metric in file:
        available_files_for_metric.append(file)

# %%
dataframes = []

for file in available_files_for_metric:
    print(file)
    df = pd.read_csv(file)
    dataframes.append(df)
# Out:
# 1_raw_databases/ukhsa_cases_data/femaleCases_region_2022.csv
# 1_raw_databases/ukhsa_cases_data/femaleCases_region_2023.csv
# 1_raw_databases/ukhsa_cases_data/femaleCases_region_2021.csv
# 1_raw_databases/ukhsa_cases_data/femaleCases_region_2020.csv

# %%
combined_df = pd.concat(dataframes, ignore_index=True)
combined_df
# Out:
#               date area_type  area_code                 area_name  \
# 0       2022-01-01    region  E12000005             West Midlands
# 1       2022-01-01    region  E12000005             West Midlands
# 2       2022-01-01    region  E12000005             West Midlands
# 3       2022-01-01    region  E12000005             West Midlands
# 4       2022-01-01    region  E12000005             West Midlands
# ...            ...       ...        ...                       ...
# 220585  2020-12-31    region  E12000003  Yorkshire and The Humber
# 220586  2020-12-31    region  E12000003  Yorkshire and The Humber
# 220587  2020-12-31    region  E12000003  Yorkshire and The Humber
# 220588  2020-12-31    region  E12000003  Yorkshire and The Humber
# 220589  2020-12-31    region  E12000003  Yorkshire and The Humber
#
#              metric   metric_name  value
# 0       femaleCases  Female cases  11465
# 1       femaleCases  Female cases  14646
# 2       femaleCases  Female cases  23957
# 3       femaleCases  Female cases  56532
# 4       femaleCases  Female cases  57590
# ...             ...           ...    ...
# 220585  femaleCases  Female cases  12510
# 220586  femaleCases  Female cases   6825
# 220587  femaleCases  Female cases   3908
# 220588  femaleCases  Female cases   3071
# 220589  femaleCases  Female cases   9871
#
# [220590 rows x 7 columns]

# %% [markdown]
# ### Save file as CSV

# %%
combined_df.to_csv(f"2_processed_databases/ukhsa_cases_data/{selected_metric}.csv", index=False)
